# %%
# To support both python 2 and python 3
# 让这份笔记同步支持 python 2 和 python 3
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %% [markdown]
# **1. Draw an example (of your own invention) of a partition of two-
# dimensional feature space that could result from recursive binary
# splitting. Your example should contain at least six regions. Draw a
# decision tree corresponding to this partition. Be sure to label all as-
# pects of your figures, including the regions R 1 ,R 2 ,..., the cutpoints
# t 1 ,t 2 ,..., and so forth.
# Hint: Your result should look something like Figures 8.1 and 8.2.**

# %%
plt.figure(figsize=(18,5))
plt.subplot(1,2,1)
plt.xlim(0,30)
plt.ylim(0,20)
plt.xticks([0,10,20,30])
plt.yticks([0,10,20])
plt.hlines(10, xmin=0, xmax=30,color = 'black')
plt.vlines(10, ymin=0, ymax=20,color = 'black')
plt.vlines(20, ymin=0, ymax=20,color = 'black')
regions_dict = {'R1':[5,5],'R2':[15,5],'R3':[25,5],'R4':[5,15],'R5':[15,15],'R6':[25,15]}
for region in regions_dict:
    plt.annotate(region,regions_dict[region],fontsize = 16)
plt.text(-1,10,'t1',horizontalalignment='right', verticalalignment='center',fontsize = 16)
plt.text(10,21,'t2/t4',horizontalalignment='center', verticalalignment='bottom',fontsize = 16)
plt.text(20,21,'t3/t5',horizontalalignment='center', verticalalignment='bottom',fontsize = 16)
plt.subplot(1,2,2)
plt.ylim(5,35)
plt.xlim(-20,30)
tesx_dict = {'y < 10(t1)':[0,35],'x < 10(t2)':[-10,25],'x < 10(t4)':[10,25],
            'R1':[-15,15],'x < 20(t3)':[-5,15],'R4':[5,15],'x < 20(t5)':[15,15],
            'R2':[-10,5],'R3':[0,5],'R5':[10,5],'R6':[20,5]}
for text in tesx_dict:
    plt.annotate(text,tesx_dict[text],fontsize = 16)
line_list = [((0,-10),(35,25)),((0,10),(35,25)),((-10,-15),(25,15)),((-10,-5),(25,15)),((10,5),(25,15)),
             ((10,15),(25,15)),((-5,-10),(15,5)),((-5,0),(15,5)),((15,10),(15,5)),((15,20),(15,5))]
for line in line_list:
    plt.plot(line[0],line[1],'k:')
plt.axis('off')
plt.show()
